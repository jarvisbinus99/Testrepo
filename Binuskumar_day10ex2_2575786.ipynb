# %%
# %matplotlib inline
import pandas as pd

# %%
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\titles.csv"
titles = pd.read_csv(file_path)
titles.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %%
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
#what are the 10  most common movies name of all times.


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Group by movie title and count occurrences
movie_name_counts = cast['title'].value_counts()

# Get the top 10 most common movie names
top_10_movie_names = movie_name_counts.head(10)

# Display the result
print(top_10_movie_names)
# Out:
# Around the World in 80 Days           1364
# Hello Au Revoir                        726
# 7 cajas                                689
# Thelma                                 593
# The Ten Commandments                   536
# The Eschatrilogy: Book of the Dead     517
# Cockneys vs Zombies                    496
# Catching Faith                         492
# The Dark Knight Rises                  458
# The Buccaneer                          437
# Name: title, dtype: int64

# %%
#which three years of the 1930s sqe the most film releases.


# Read the titles DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
titles = pd.read_csv(file_path)

# Filter movies released in the 1930s
movies_1930s = titles[(titles['year'] >= 1930) & (titles['year'] < 1940)]

# Count the number of movies released in each year
movie_counts_by_year = movies_1930s['year'].value_counts()

# Get the top three years with the most film releases
top_3_years = movie_counts_by_year.head(3)

# Display the result
print(top_3_years)
# Out:
# 1937    27676
# 1936    26019
# 1938    25450
# Name: year, dtype: int64

# %%
#plot the number of films that have been released each decade over the history of cinema

import matplotlib.pyplot as plt

# Read the titles DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
titles = pd.read_csv(file_path)

# Extract the decade from the 'year' column
titles['decade'] = (titles['year'] // 10) * 10

# Group the data by decade and count the number of films
decade_counts = titles['decade'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(10, 6))
plt.bar(decade_counts.index, decade_counts.values, width=8, align='center', tick_label=decade_counts.index)
plt.xlabel('Decade')
plt.ylabel('Number of Films Released')
plt.title('Number of Films Released Each Decade')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Ploat the number of "Hamlet" films made each decade.

import matplotlib.pyplot as plt

# Read the titles DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
titles = pd.read_csv(file_path)

# Filter movies with the title "Hamlet"
hamlet_movies = titles[titles['title'] == 'Hamlet']

# Extract the decade from the 'year' column for Hamlet movies
hamlet_movies['decade'] = (hamlet_movies['year'] // 10) * 10

# Group the data by decade and count the number of "Hamlet" films
hamlet_counts_by_decade = hamlet_movies['decade'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(10, 6))
plt.bar(hamlet_counts_by_decade.index, hamlet_counts_by_decade.values, width=8, align='center', tick_label=hamlet_counts_by_decade.index)
plt.xlabel('Decade')
plt.ylabel('Number of "Hamlet" Films')
plt.title('Number of "Hamlet" Films Made Each Decade')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_80384\241702946.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_movies['decade'] = (hamlet_movies['year'] // 10) * 10

# %%
#what are the 11 most common character names in movie history.


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Group by character names and count occurrences
character_counts = cast['character'].value_counts()

# Get the top 11 most common character names
top_11_characters = character_counts.head(11)

# Display the result
print(top_11_characters)
# Out:
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Herself         6705
# Name: character, dtype: int64

# %%
#who are the 10 people most often credits as Himself in a film history.


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for rows where the character name is "Himself"
himself_credits = cast[cast['character'] == 'Himself']

# Group by actor's name and count occurrences
himself_counts = himself_credits['name'].value_counts()

# Get the top 10 people most often credited as "Himself"
top_10_himself_actors = himself_counts.head(10)

# Display the result
print(top_10_himself_actors)
# Out:
# Adolf Hitler             99
# Richard Nixon            44
# Ronald Reagan            41
# John F. Kennedy          37
# George W. Bush           25
# Winston Churchill        24
# Martin Luther King       23
# Ron Jeremy               22
# Bill Clinton             22
# Franklin D. Roosevelt    21
# Name: name, dtype: int64

# %%
#which actor or actoress apperar in the most movies in the yera 1945.


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for movies released in 1945
movies_1945 = cast[cast['year'] == 1945]

# Group by actor's name and count appearances
actor_appearances = movies_1945['name'].value_counts()

# Get the actor or actress with the most appearances in 1945
most_appearances_actor = actor_appearances.idxmax()
num_appearances = actor_appearances.max()

# Display the result
print(f"The actor/actress with the most appearances in 1945 is {most_appearances_actor} with {num_appearances} appearances.")
# Out:
# The actor/actress with the most appearances in 1945 is Emmett Vogan with 39 appearances.

# %%
#which actor or actoress apperar in the most movies in the yera 1985.


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for movies released in 1985
movies_1985 = cast[cast['year'] == 1985]

# Group by actor's name and count appearances
actor_appearances = movies_1985['name'].value_counts()

# Get the actor or actress with the most appearances in 1985
most_appearances_actor = actor_appearances.idxmax()
num_appearances = actor_appearances.max()

# Display the result
print(f"The actor/actress with the most appearances in 1985 is {most_appearances_actor} with {num_appearances} appearances.")
# Out:
# The actor/actress with the most appearances in 1985 is Mammootty with 22 appearances.

# %%
#ploat how many roles mommootty has played in each year career.

import matplotlib.pyplot as plt

# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles played by Mammootty
mammootty_roles = cast[cast['name'] == 'Mammootty']

# Group by the year and count roles
roles_by_year = mammootty_roles['year'].value_counts().sort_index()

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(roles_by_year.index, roles_by_year.values, marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Number of Roles Played by Mammootty')
plt.title('Number of Roles Played by Mammootty Each Year')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
#what are the 10 most frequent roles that starts  within the phares "Patron in".


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles that start with "Patron in"
patron_in_roles = cast[cast['character'].str.startswith('Patron in')]

# Group by role names and count occurrences
role_counts = patron_in_roles['character'].value_counts()

# Get the top 10 most frequent roles
top_10_roles = role_counts.head(10)

# Display the result
print(top_10_roles)
# Out:
# Patron in Frisky Rabbit         16
# Patron in Chinese Restaurant     9
# Patron in the Coffee House       9
# Patron in Billiard Parlor        5
# Patron in restaurant             4
# Patron in Bar                    4
# Patron in cabaret                3
# Patron in Restaurant             3
# Patron in Club                   3
# Patron in booth                  2
# Name: character, dtype: int64

# %%
#What are the 10 most frequent roles that starts with the word "Science".


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles that start with "Science"
science_roles = cast[cast['character'].str.startswith('Science')]

# Group by role names and count occurrences
role_counts = science_roles['character'].value_counts()

# Get the top 10 most frequent roles
top_10_roles = role_counts.head(10)

# Display the result
print(top_10_roles)
# Out:
# Science Teacher         60
# Science Student          9
# Science Fair Student     9
# Science Fair Judge       6
# Science Fair Kid         5
# Science Reporter         5
# Science Kid              5
# Science Club Member      5
# Science Promo Cadet      5
# Science                  4
# Name: character, dtype: int64

# %%
#Plot the n value of the role that judi dench has played over her career.

import matplotlib.pyplot as plt

# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles played by Judi Dench
judi_dench_roles = cast[cast['name'] == 'Judi Dench']

# Filter out rows with NaN values in the 'n' column
judi_dench_roles = judi_dench_roles.dropna(subset=['n'])

# Plot the 'n' values over the years
plt.figure(figsize=(12, 6))
plt.plot(judi_dench_roles['year'], judi_dench_roles['n'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('n Value of Roles Played by Judi Dench')
plt.title('n Value of Roles Played by Judi Dench Over Her Career')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
#ploat the n value of the cary grant role through career.

import matplotlib.pyplot as plt

# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles played by Cary Grant
cary_grant_roles = cast[cast['name'] == 'Cary Grant']

# Filter out rows with NaN values in the 'n' column
cary_grant_roles = cary_grant_roles.dropna(subset=['n'])

# Plot the 'n' values over the years
plt.figure(figsize=(12, 6))
plt.plot(cary_grant_roles['year'], cary_grant_roles['n'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('n Value of Roles Played by Cary Grant')
plt.title('n Value of Roles Played by Cary Grant Over His Career')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Plot the n value of the that sidney poitier has acted over the year.

import matplotlib.pyplot as plt

# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles played by Sidney Poitier
sidney_poitier_roles = cast[cast['name'] == 'Sidney Poitier']

# Filter out rows with NaN values in the 'n' column
sidney_poitier_roles = sidney_poitier_roles.dropna(subset=['n'])

# Plot the 'n' values over the years
plt.figure(figsize=(12, 6))
plt.plot(sidney_poitier_roles['year'], sidney_poitier_roles['n'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('n Value of Roles Played by Sidney Poitier')
plt.title('n Value of Roles Played by Sidney Poitier Over His Career')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
#How many leading (n=1) roles were avilable  to actors,and how many actresses in 1950's. 


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles with n=1 in the 1950s for actors
leading_roles_actors_1950s = cast[(cast['year'] >= 1950) & (cast['year'] <= 1959) & (cast['n'] == 1) & (cast['type'] == 'actor')]

# Filter for roles with n=1 in the 1950s for actresses
leading_roles_actresses_1950s = cast[(cast['year'] >= 1950) & (cast['year'] <= 1959) & (cast['n'] == 1) & (cast['type'] == 'actress')]

# Count the number of leading roles for actors and actresses
num_leading_roles_actors = len(leading_roles_actors_1950s)
num_leading_roles_actresses = len(leading_roles_actresses_1950s)

# Display the results
print(f"Number of leading roles (n=1) available to actors in the 1950s: {num_leading_roles_actors}")
print(f"Number of leading roles (n=1) available to actresses in the 1950s: {num_leading_roles_actresses}")
# Out:
# Number of leading roles (n=1) available to actors in the 1950s: 6692
# Number of leading roles (n=1) available to actresses in the 1950s: 3040

# %%
#How many leading (n=2) roles were avilable  to actors,and how many actresses in 1950's. 


# Read the cast DataFrame
file_path = r"C:\Users\hp\Desktop\practice exercises\Python-S1\cast.csv"
cast = pd.read_csv(file_path)

# Filter for roles with n=2 in the 1950s for actors
leading_roles_actors_1950s = cast[(cast['year'] >= 1950) & (cast['year'] <= 1959) & (cast['n'] == 2) & (cast['type'] == 'actor')]

# Filter for roles with n=2 in the 1950s for actresses
leading_roles_actresses_1950s = cast[(cast['year'] >= 1950) & (cast['year'] <= 1959) & (cast['n'] == 2) & (cast['type'] == 'actress')]

# Count the number of leading roles for actors and actresses
num_leading_roles_actors = len(leading_roles_actors_1950s)
num_leading_roles_actresses = len(leading_roles_actresses_1950s)

# Display the results
print(f"Number of leading roles (n=2) available to actors in the 1950s: {num_leading_roles_actors}")
print(f"Number of leading roles (n=2) available to actresses in the 1950s: {num_leading_roles_actresses}")
# Out:
# Number of leading roles (n=2) available to actors in the 1950s: 4640
# Number of leading roles (n=2) available to actresses in the 1950s: 4635
